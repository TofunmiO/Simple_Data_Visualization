# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %%
data = pd.read_csv('nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.iloc[0]
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height               2-Jun
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: 0, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data.plot()

# %%
fig,ax = plt.subplots()
ax.plot(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter'],[180,235,205,185])

# %%
# data.plot(x="Number", y= 'Age', kind="line")
